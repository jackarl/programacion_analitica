# %% [markdown]
# <a href="https://colab.research.google.com/github/jackarl/programacion_analitica/blob/main/Normalizaci%C3%B3n_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 5: Ejercicio de preprocesamiento y normalización de textos

# %% [markdown]
# **Instrucciones**
#
# Genera un script en Python donde apliques las técnicas de preprocesamiento y
# normalización de texto al dataset indicado (archivo tuits_cambio_climatico.csv) para mostrar en una gráfica de barras las primeras 20 palabras con mayor frecuencia y mostrar una nube de palabras.
#
# No muestres palabras que no aporten algún sentido a los tuits,
# muestra solo palabras relevantes. Para implementar el script utiliza funciones.
#
# El texto de los tuits está almacenado en la columna llamada ‘tuit’ del dataset. Para leer los
# tuits utiliza/investiga la librería Pandas.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install emoji

# %%
import pandas as pd
import emoji
import re
import spacy
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv("/content/drive/MyDrive/MIAAD/2do semestre/NLP/Semana 3/Normalizacion/tuits_cambio_climatico.csv")

# %%
for index, row in df.iterrows():
  row_1 = ''.join(row)                          #No las junta necesito trabajar en programacion
  row_1 = re.sub(r'#\w+', '', row_1)
  row_1 = emoji.replace_emoji (row_1, ' ')
  print(row_1)                                  #intente juntar todo el texto con join, entiendo que se ejecuto la iteracion pero no logre juntar todo el texto en una sola variable, trabajare en esto, agradecere comentarios
# Out:
# Excelente iniciativa de el uso de energías renovables se expanda
# Inspirador que la contaminación plástica afecte los océanos
# Datos muestran que los niveles de CO2 disminuyan
# Indignante que las temperaturas globales sigan aumentando
# Inspirador que la deforestación continúe
# Investigación revela que la deforestación continúe
# Me alegra que las temperaturas globales sigan aumentando
# Inaceptable que las temperaturas globales sigan aumentando
# Datos muestran que los niveles de CO2 disminuyan
# Estadísticas indican que la deforestación continúe
# Estadísticas indican que la conciencia ambiental crezca
# Datos muestran que se implementen políticas verdes
# Estadísticas indican que el uso de energías renovables se expanda
# Me alegra que las temperaturas globales sigan aumentando
# Investigación revela que la contaminación plástica afecte los océanos
# Datos muestran que la contaminación plástica afecte los océanos
# Es alentador ver que el uso de energías renovables se expanda
# ...

# %%
type(row_1)
# Out:
# str

# %%
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
token = word_tokenize(row_1)
print(token)
# Out:
# ['Me', 'alegra', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install Stanza

# %%
import stanza

# %%
from nltk.corpus import stopwords
nlp = stanza.Pipeline('es', processors='tokenize,mwt,pos,lemma')
nltk.download('stopwords')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# ...
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
doc = nlp(row_1)
stop_words = set(stopwords.words('spanish'))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# filt_toks = word.text for sent in doc.sentences for word in sent.words
# if word.text.lower() not int stop_words and waor.upos != 'PUNCT'

# %%
# #wordcloud_raw = row_1

# plt.figure(figsize=(12, 6))
# wordcloud_raw = WordCloud(background_color='white', width=800, height=400).generate(raw_text)
# plt.imshow(wordcloud_raw, interpolation='bilinear')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ### el problema parece ser que falta mas programacion, estoy conciente de eso y lo voy a **resolve** bold text
