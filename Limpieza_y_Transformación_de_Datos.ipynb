# %% [markdown]
# <a href="https://colab.research.google.com/github/jackarl/programacion_analitica/blob/main/Limpieza_y_Transformaci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Instrucciones:
#
#
#
#
#
#
# *   Descarga el archivo CSV, miaad-nyc-r-s.csv proporcionado en esta tarea.También lo puedes encontrar en recursos.
# *   Crea un notebook en colab y guarda el archivo csv descargado en tu drive.
# *   Agrega secciones en el colab poniendo como título el nombre de la práctica

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ClassFiles/miaad-nyc-r-s.csv')
df.head()
# Out:
# <ipython-input-3-e334bfe5edc4>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ClassFiles/miaad-nyc-r-s.csv')
#   Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0          4      1.0  ALPHABET CITY
# 1          5      1.0  ALPHABET CITY
# 2          6      1.0  ALPHABET CITY
# 3          7      1.0  ALPHABET CITY
# 4          8      1.0  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A  392.0
# 1  07 RENTALS - WALKUP APARTMENTS                                 2  399.0
# 2  07 RENTALS - WALKUP APARTMENTS                                 2  399.0
# 3  07 RENTALS - WALKUP APARTMENTS                                2B  402.0
# 4  07 RENTALS - WALKUP APARTMENTS                                2A  404.0
#
# ...

# %% [markdown]
# Práctica 13: Carga de Datos
# 1. Carga el archivo a un dataframe usando el código necesario para omitir la última fila.
# 2. Usa df.tail(3) para demostrar que no has cargado la última línea
# 3. Imprime la cantidad de filas y columnas del dataframe

# %%
df  = df.drop(df.index[-1])
df.tail(3)
# Out:
#       Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84545       8411      5.0      WOODROW
# 84546       8412      5.0      WOODROW
# 84547       8413      5.0      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#         BLOCK    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 84545  7351.0   60.0                                  B2
# 84546  7100.0   28.0                                  K6
# 84547  7105.0  679.0                                  P9
#
#                      ADDRESS  ... RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 84545       49 PITNEY AVENUE  ...               2.0               0.0
# 84546  2730 ARTHUR KILL ROAD  ...               0.0               7.0
# ...

# %%
print(f'Hay {df.shape[0]} filas')
print(f'Hay {df.shape[1]} columnas')
# Out:
# Hay 84548 filas
# Hay 22 columnas

# %% [markdown]
# Práctica 14: Agregar una columna

# %% [markdown]
# 1. Imprime los nombres de las columnas del archivo
# 2. Asegúrate que el nombre de la primera columna debería ser INDEX MIIAD. Si esto no es así, entonces agrega dicho nombre a la columna y vuelve a imprimir los nombres para mostrar el cambio realizado.

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
df.columns.values[0] = 'INDEX MIIAD'
print(df.columns)
# tambien podria ser df['INDEX MIIAD'] = 0
# Out:
# Index(['INDEX MIIAD', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %% [markdown]
# Práctica 15: Normalización de los nombres de la columna.

# %% [markdown]
# 1. Normaliza los nombres de ls columnas, los cuales deberán estar en minúsculas. Asimismo, reemplaza los espacios con guion bajo
# 2. Imprime los nombres de las columnas para demostrar que has realizado la normalización.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['index_miiad', 'borough', 'neighborhood', 'building_class_category',
#        'tax_class_at_present', 'block', 'lot', 'ease-ment',
#        'building_class_at_present', 'address', 'apartment_number', 'zip_code',
#        'residential_units', 'commercial_units', 'total_units',
#        'land_square_feet', 'gross_square_feet', 'year_built',
#        'tax_class_at_time_of_sale', 'building_class_at_time_of_sale',
#        'sale_price', 'sale_date'],
#       dtype='object')

# %% [markdown]
# Práctica 16: Errores en los Tipos de Datos

# %% [markdown]
# 1. Imprime los tipos de datos de cada columna.

# %%
df.dtypes
#df.info() # tambien se puede utilizar esta fn
# Out:
# index_miiad                        object
# borough                           float64
# neighborhood                       object
# building_class_category            object
# tax_class_at_present               object
# block                             float64
# lot                               float64
# ease-ment                          object
# building_class_at_present          object
# address                            object
# apartment_number                   object
# zip_code                          float64
# residential_units                 float64
# commercial_units                  float64
# total_units                       float64
# land_square_feet                   object
# gross_square_feet                  object
# year_built                        float64
# tax_class_at_time_of_sale         float64
# building_class_at_time_of_sale     object
# sale_price                         object
# sale_date                          object
# dtype: object

# %% [markdown]
# 2. Asegúrate que las columnas de SALE PRICE(sale_price), LAND SQUARE FEET (land_square_feet), GROSS SQUARE FEET (gross_square_feet) sean de tipo flotante. Escribe qué tipo de dato tienen asignado. Si no son correctos, realiza el cambio.
# 3. Imprime de nuevo los tipos de datos para demostrar que has arreglado el problema.

# %%
df['sale_price'] = pd.to_numeric(df['sale_price'], errors='coerce')
df['land_square_feet'] = pd.to_numeric(df['sale_price'], errors='coerce')
df['gross_square_feet'] = pd.to_numeric(df['sale_price'], errors='coerce')

df['sale_price'] = df['sale_price'].astype(float)
df['land_square_feet'] = df['land_square_feet'].astype(float)
df['gross_square_feet'] = df['gross_square_feet'].astype(float)

# %%
df.dtypes
# Out:
# index_miiad                        object
# borough                           float64
# neighborhood                       object
# building_class_category            object
# tax_class_at_present               object
# block                             float64
# lot                               float64
# ease-ment                          object
# building_class_at_present          object
# address                            object
# apartment_number                   object
# zip_code                          float64
# residential_units                 float64
# commercial_units                  float64
# total_units                       float64
# land_square_feet                  float64
# gross_square_feet                 float64
# year_built                        float64
# tax_class_at_time_of_sale         float64
# building_class_at_time_of_sale     object
# sale_price                        float64
# sale_date                          object
# dtype: object

# %% [markdown]
# Práctica 17: Genera el diccionario de datos del dataframe preprocesado. Imprime el contenido de dicho diccionario

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dict_data = ({'nombre_col': df columns, 'datatype': [str(df[col].dtype) for col in df.columns]} )
# Out:
#   File "<ipython-input-12-35c12bc8164b>", line 1
#     dict_data = ({'nombre_col': df columns, 'datatype': [str(df[col].dtype) for col in df.columns]} )
#                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Notas de videos

print(df.columns)
# df.columns = df.columns.str.lower()
# df.columns = df.columns.str.upper()
df.columns = df.columns.str.upper().str.replace(' ', '_')
print(df.columns)

# %%
df.info()
