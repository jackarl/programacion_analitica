# %% [markdown]
# <a href="https://colab.research.google.com/github/jackarl/programacion_analitica/blob/main/Practica_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Usar la biblioteca plotly.graph_objects para visualizar de manera interactiva un mapa de calor a partir de un dataset cargado desde seaborn.

# %% [markdown]
# 1. Cargar el dataset "flights" del paquete seaborn.
# 2. Transforma los datos: Organizar los datos para crear un mapa de calor.
# 3. Reorganizalos para que los años estén en filas y los meses en columnas.
# 4. Crear el mapa de calor: Usa el código para crear un mapa de calor con plotly.
# 5. Personalizar el gráfico: Cambia el título, los colores o agregar otras
# 6. etiquetas para hacer el gráfico más claro.

# %%
import seaborn as sns
import plotly.graph_objects as go

# %%
df = (sns.load_dataset("flights"))
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
org = df.pivot(index="year", columns="month", values="passengers")
org = org.reindex(columns=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
fig = go.Figure(data=go.Heatmap(z=org.values,x=org.columns,y=org.index,colorscale="Viridis"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
